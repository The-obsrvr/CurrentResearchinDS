# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling

# %%
data = pd.read_csv("data/bank-additional-full.csv",  delimiter=';', index_col=0)

# %%
data.sample(5)
# Out:
#        Unnamed: 0  age            job     marital            education  \
# 27426       27426   41   "technician"   "married"  "university.degree"
# 2794         2794   42       "admin."   "married"           "basic.9y"
# 26937       26937   41  "blue-collar"   "married"           "basic.6y"
# 38598       38598   59      "retired"  "divorced"           "basic.4y"
# 26910       26910   43  "blue-collar"   "married"            "unknown"
#
#          default housing  loan      contact  month  ... campaign  pdays  \
# 27426       "no"   "yes"  "no"   "cellular"  "nov"  ...        5    999
# 2794        "no"   "yes"  "no"  "telephone"  "may"  ...        6    999
# 26937       "no"   "yes"  "no"  "telephone"  "nov"  ...        6    999
# 38598       "no"   "yes"  "no"  "telephone"  "oct"  ...        4    999
# 26910  "unknown"   "yes"  "no"   "cellular"  "nov"  ...        6    999
#
#        previous       poutcome  emp.var.rate cons.price.idx  cons.conf.idx  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0          age      duration      campaign         pdays  \
# count  41188.00000  41188.00000  41188.000000  41188.000000  41188.000000
# mean   20593.50000     40.02406    258.285010      2.567593    962.475454
# std    11890.09578     10.42125    259.279249      2.770014    186.910907
# min        0.00000     17.00000      0.000000      1.000000      0.000000
# 25%    10296.75000     32.00000    102.000000      1.000000    999.000000
# 50%    20593.50000     38.00000    180.000000      2.000000    999.000000
# 75%    30890.25000     47.00000    319.000000      3.000000    999.000000
# max    41187.00000     98.00000   4918.000000     56.000000    999.000000
#
#            previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# count  41188.000000  41188.000000    41188.000000   41188.000000
# mean       0.172963      0.081886       93.575664     -40.502600
# std        0.494901      1.570960        0.578840       4.628198
# ...

# %%
profile = data.profile_report(title='Pandas Profiling Report')
profile.to_file(output_file="fifa_pandas_profiling.html")

# %%
corr = data.corr()
corr.style.background_gradient(cmap='RdBu_r').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col1 {
#             background-color:  #0f437b;
#             color:  #f1f1f1;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col2 {
#             background-color:  #1a5899;
#             color:  #f1f1f1;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col4 {
#             background-color:  #3f8ec0;
#             color:  #000000;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col5 {
#             background-color:  #f9c6ac;
#             color:  #000000;
#         }    #T_246fafb4_26a0_11eb_bba4_68071549f3dfrow0_col6 {
#             background-color:  #053061;
#             color:  #f1f1f1;
# ...

# %%
pd.plotting.scatter_matrix(data, alpha=0.2, figsize=(20, 15));
